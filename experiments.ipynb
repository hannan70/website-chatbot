# %%
import os
from dotenv import load_dotenv
load_dotenv()

# load env variable
groq_api_kay = os.environ.get('GROQ_API_KEY')

from langchain_groq import ChatGroq
from langchain_huggingface import HuggingFaceEmbeddings
from langchain.document_loaders import WebBaseLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_chroma import Chroma
from langchain.chains import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain

# %%
llm = ChatGroq(model='llama-3.3-70b-versatile', api_key=groq_api_kay)

# %%
urls = [
    "https://citylocalbiz.us/",
    "https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210",
    "https://citylocalbiz.us/buy-credit",
    "https://citylocalbiz.us/terms-conditions",
    "https://citylocalbiz.us/privacy-policy",
    "https://citylocalbiz.us/blog",
    "https://citylocalbiz.us/about",
    "https://citylocalbiz.us/contact",
    "https://citylocalbiz.us/sign-up#google_vignette",
    "https://citylocalbiz.us/login",
    "https://citylocalbiz.us/package-price",
    "https://citylocalbiz.us/states",
    "https://citylocalbiz.us/cities",
    "https://citylocalbiz.us/categories"
]

loader = WebBaseLoader(web_path=urls)
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content="\n\n\n\n\n\nDiscover Local Businesses - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nJoin Us & Explore Thousands of Local Places\nFind the place you want and search the best place everything is here.\n\n\n\n\n\n\nKeywords\n\n\n\n\n\n\n\nWhere\n\nSelect States\nAlabama (AL)\nAlaska (AK)\nAlberta (AB)\nArizona (AZ)\nArkansas (AR)\nBritish Columbia (BC)\nCalifornia (CA)\nColorado (CO)\nConnecticut (CT)\nDelaware (DE)\nDistrict of Columbia (DC)\nFlorida (FL)\nGeorgia (GA)\nHawaii (HI)\nIdaho (ID)\nIllinois (IL)\nIndiana (IN)\nIowa (IA)\nKansas (KS)\nKentucky (KY)\nLouisiana (LA)\nMaine (ME)\nManitoba (MB)\nMaryland (MD)\nMassachusetts (MA)\nMichigan (MI)\nMinnesota (MN)\nMississippi (MS)\nMissouri (MO)\nMontana (MT)\nNebraska (NE)\nNevada (NV)\nNew Brunswick (NB)\nNew Hampshire (NH)\nNew Jersey (NJ)\nNew Mexico (NM)\nNew York (NY)\nNewfoundland and Labrador (NL)\nNorth Carolina (NC)\nNorth Dakota (ND)\nNorthwest Territories (NT)\nNova Scotia (NS)\nNunavut (NU)\nOhio (OH)\nOklahoma (OK)\nOntario (ON)\nOregon (OR)\nPennsylvania (PA)\nPrince Edward Island (PE)\nQuebec (QC)\nRhode Island (RI)\nSaskatchewan (SK)\nSouth Carolina (SC)\nSouth Dakota (SD)\nTennessee (TN)\nTexas (TX)\nUtah (UT)\nVermont (VT)\nVirginia (VA)\nWashington (WA)\nWest Virginia (WV)\nWisconsin (WI)\nWyoming (WY)\nYukon (YT)\n\n\n\n\nSearch\n\n\n\n\n\nPopular Search :\ngarage+door,\nsummers plumbing heating,\nheating, cooling,\nstellrr+insulation+,\nhunt’s kitchen\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nStates\nUSA & Canada top regions\n\n\n\n\n\n                                            California\n                                            3590\n\n\n\n\n                                            Texas\n                                            2634\n\n\n\n\n                                            Florida\n                                            2396\n\n\n\n\n                                            New York\n                                            2120\n\n\n\n\n                                            New Jersey\n                                            804\n\n\n\n\n                                            Georgia\n                                            800\n\n\n\n\n                                            Illinois\n                                            778\n\n\n\n\n                                            Arizona\n                                            739\n\n\n\n\n                                            Pennsylvania\n                                            670\n\n\n\n\n                                            Colorado\n                                            613\n\n\n\nAll States\n\n\n\n\n\n\n\nCities\nUSA & Canada top cities\n\n\n\n\n\n                                            New York\n                                            837\n\n\n\n\n                                            Houston\n                                            395\n\n\n\n\n                                            Los Angeles\n                                            380\n\n\n\n\n                                            Miami\n                                            282\n\n\n\n\n                                            Charleston\n                                            270\n\n\n\n\n                                            Brooklyn\n                                            264\n\n\n\n\n                                            Las V ...
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content="\n\n\n\n\n\nCharter Spectrum Cable & Internet - Portland, OR\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCharter Spectrum Cable & Internet\n                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\nUnclaim\n\n\n\n\n                                                    This business has not yet been claimed by the owner or a representative.\n                                                    \n\nClaim this business to view business & Make it easier for local customers to find you by keeping your business with Trust.\n                                                    \n\n\n\n\n\n\n0/\xa0 0 Rating\n                                      \n\n\n\n855-441-9844\n\n\n                                                  Visit Website \n\n\n\n\n\n3055 NW Yeon Ave #546 Portland OR 97210 \n\n\n\n\nSubmitted By  charterportland\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\nSubmit Review\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechnology\n\n\n\n\n ⇨ Internet Services\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout this business\n\n\n\n\n\n\n\n\n\nGallery\n\n\n\n\n\n\n\n\n\n\n\nMap\n\n\n\n\n\n\n\n\n\n\n\n\nReview\n\n\nLeave A Review\n\n\n\n\n\n0\n\n0 review\n\n\n\n\nService\n\n\n\nCo-operation\n\n\n\nQuality\n\n\n\nPrice\n\n\n\n\n\n\n\n\n\n\n\n\nAdd Review\n\n\n \n\n\nService\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nCo-Operation\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nQuality\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nPrice\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\n\n\n\n\n\nSubmit Review\n\n\n\n\n\n\n\n\n\n\n\n\nBusiness Information\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCharter Spectrum Cable & Internet\n                                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\nPortland OR\n\n\n\n\n\n\nCategories:\n\n\n\n\n                                                                Technology\n                                                            \n\n\n\n\n\nPhone Number:\n\n\n855-441-9844\n\n\n\n\nPublish Date:\n\n\n 5 years ago\n\n\n\n\n\n                                                    Visit Website   \n\n\n\n\n\n\n\n\nNearby Company\n\n\n\n\n\n\n\n\nWeaver Synthetics\n 5730 SW Shattuck Rd, Portland OR\n  503-244-9394 \n\n\n\n\n\n\n\n\n\ntelevision price in bangladesh\n 1376 Kincheloe Road, Portland OR\n  5034754664 \n\n\n\n\n\n\n\n\n\nIBR Infotech\n 2759 NE Whitaker Way, # F133, Portland, Oregon, 97230, US, Portland OR\n  5035757893 \n\n\n\n\n\n\n\n\n\nHappy Haus\n Portland, OR, USA, Portland OR\n  9713302226 \n\n\n\n\n\n\n\n\n\nAva Health\n 5117 SE Powell Blvd. #3, US, Portland OR\n  (503) 777-7097 \n\n\n\n\n\n\n\n\n\nOnie's Auto - Cash for Cars\n 5325 N Columbia Blvd, Portland OR\n  971-284-1906 \n\n\n\n\n\n\n\n\n\nFalcon Services\n 10180 SW Park Way, Portland OR\n  (503) 208-4709 \n\n\n\n\n\n\n\n\n\nAffordable Junk Removal LLC\n 6639 SE 65th Ave, Portland OR\n  503-354-7887 \n\n\n\n\n\n\n\n\n\nSunset Heating & Cooling\n 607 S Idaho Street #100, Portland OR\n  (503) 234-0611 \n\n\n\n\n\n\n\n\n\nServerpartsworld\n Serverpartsworld International, Inc. 15727 NE Russell St, Portland OR\n  (503) 252-9361 \n\n\n\n\n\n\n\nPrice Range\n\n\n\nN/A\n\n\n\n\n\n Related Search\n\n\n\ngarage+door\nsummers plumbing heating\nheating, cooling\nstellrr+ ...
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='\n\n\n\n\n\nChoose a Package - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nBuy Credits\nRisk free purchase at anytime. no questions, no hastle\n\n\n\n\n\n\nMini\n50 Credits\n\n\n\n0 Bonus Credits\n50 Credits\nunlimited Validity\n\n\n\nBuy $3.49\n\n\n\n\n\n\nMedium\n100 Credits\n\n\n\n5 Bonus Credits\n100 Credits\nunlimited Validity\n\n\n\nBuy $4.99\n\n\n\n\n\n\nLarge\n200 Credits\n\n\n\n10 Bonus Credits\n200 Credits\nunlimited Validity\n\n\n\nBuy $9.99\n\n\n\n\n\n\nBronze\n400 Credits\n\n\n\n20 Bonus Credits\n400 Credits\nunlimited Validity\n\n\n\nBuy $19.99\n\n\n\n\n\n\nSilver\n1000 Credits\n\n\n\n80 Bonus Credits\n1000 Credits\nunlimited Validity\n\n\n\nBuy $49.99\n\n\n\n\n\n\nGold\n2000 Credits\n\n\n\n200 Bonus Credits\n2000 Credits\nunlimited Validity\n\n\n\nBuy $99.00\n\n\n\n\n\n\nDiamond\n10000 Credits\n\n\n\n600 Bonus Credits\n10000 Credits\nunlimited Validity\n\n\n\nBuy $499.00\n\n\n\n\n\n\nPlatinum\n20000 Credits\n\n\n\n1200 Bonus Credits\n20000 Credits\nunlimited Validity\n\n\n\nBuy $999.00\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin with City Local Biz\n\n\n\n\n\n  Email:\n\n\n\n Password:\n\n\n\n\n\nClose\nLogin\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='\n\n\n\n\n\nTerms and Condition - City Local Biz \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nTerms and Conditions\n\n\n\n\nHome\nTerms and Conditions\n\n\n\n\n\n\n\n\n\n\n\n\n\nLast updated: August 1, 2025\n\n\n\n\n                        Welcome to City Local Biz! By accessing and using our website, you agree to comply with the following terms and conditions. Please read them carefully.\n                    \n\n\nAcceptance of Terms\n\n                        By using City Local Biz, you agree to abide by these terms, our Privacy Policy, and any additional guidelines or rules that are displayed on our website. If you do not agree with any part of these terms, kindly refrain from using our services.\n                    \n\n\nUser Responsibilities\n\n                        Users of City Local Biz must be at least 18 years old. You are responsible for maintaining the confidentiality of your account information and agree to take sole responsibility for all activities that occur under your account.\n                    \n\n\nBusiness Listings and Content\n\n                        Businesses listed on City Local Biz are responsible for the accuracy and legality of their content. We reserve the right to remove any content that violates our guidelines or is deemed inappropriate, offensive, or fraudulent.\n                    \n We are not accepting thses type of content listed\n\n  Adult Content\n  Alcohol Content\n  Casino Content\n  Cannabis Content\n  Fraud and Scams\n  Gambling Content\n  Malware Content\n  Pornography Content\n  Terrorist Content\n  Weeds Content\n\n\n\nThird-Party Links and Content\n\n                        Our website may contain links to third-party websites, services, or content that are not owned or controlled by City Local Biz. We are not responsible for the content, privacy policies, or practices of these third parties.\n                    \n\n\nLimitation of Liability\n\n                        City Local Biz and its affiliates shall not be liable for any indirect, incidental, special, consequential, or punitive damages arising from your use of the website or any content therein.\n                    \n\n\nIntellectual Property\n\n                        All content on City Local Biz, including text, graphics, logos, and images, is the property of City Local Biz or its licensors and is protected by copyright laws.\n                    \n\n\nChanges to Terms\n\n                        City Local Biz reserves the right to modify or replace these terms at any time. Your continued use of the website after changes have been made signifies your acceptance of the revised terms.\n                    \n\n\n\n                        For any questions or concerns regarding our terms and conditions, please contact us\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stie ...
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='\n\n\n\n\n\nPrivacy Policy | Safeguarding Your Data - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nPrivacy Policy\n\n\n\n\nHome\nPrivacy Policy\n\n\n\n\n\n\n\n\n\n\n\n\n\nLast updated: August 1, 2025\n\n\n\n                    Our Privacy Policy was last updated and posted on August 1, 2025. It governs the privacy terms of our Website, located at https://citylocalbiz.us, sub-domains, and any associated web-based and mobile applications (collectively, “Website”), as owned and operated by City Local Biz. Any capitalized terms not defined in our Privacy Policy, have the meaning as specified in our Terms of Service.\n                \n\n                    Your privacy is very important to us. Accordingly, we have developed this Policy in order for you to understand how we collect, use, communicate and disclose and make use of personal information. We use your Personal Information only for providing and improving the Site. By using the Site, you agree to the collection and use of information in accordance with this policy. Unless otherwise defined in this Privacy Policy, terms used in this Privacy Policy have the same meanings as in our Terms and Conditions, accessible at https://citylocalbiz.us. The following outlines our privacy policy.\n                \n\n\n\n                            * Before or at the time of collecting personal information, we will identify the purposes for which information is being collected.\n                        \n\n                            * We will collect and use of personal information solely with the objective of fulfilling those purposes specified by us and for other compatible purposes, unless we obtain the consent of the individual concerned or as required by law.\n                        \n\n                            * We will only retain personal information as long as necessary for the fulfillment of those purposes.\n                        \n\n                            * We will collect personal information by lawful and fair means and, where appropriate, with the knowledge or consent of the individual concerned.\n                        \n\n                            * Personal data should be relevant to the purposes for which it is to be used, and, to the extent necessary for those purposes, should be accurate, complete, and up-to-date.\n                        \n\n                            * We will protect personal information by reasonable security safeguards against loss or theft, as well as unauthorized access, disclosure, copying, use or modification.\n                        \n\n                            * We will make readily available to customers information about our policies and practices relating to the management of personal information.\n                        \n\n\n\nYour Privacy\n\n                        City Local Biz follows all legal requirements to protect your privacy. Our Privacy Policy is a legal statement that explains how we may collect information from you, how we may share your information, and how you can limit our sharing of your information. We utilize the Personal Data you offer in a way that is consistent with this Personal privacy Policy. If you provide Personal Data for a particular reason, we could make use of the Personal Data in connection with the reason for which it was provided. For example, registration info sent when developing your account, might be use ...
#  Document(metadata={'source': 'https://citylocalbiz.us/blog', 'title': 'All Blogs - City Local Biz', 'description': 'Find your favorite blogs', 'language': 'en'}, page_content='\n\n\n\n\n\nAll Blogs - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nOur Blogs\n\n\n\n\nHome\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nShowing\n 1-12\nof\n37 Result’s\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Technology\n\n\nThe Power of Windows VPS on DigitalOcean: Your Gateway to Seamless Performance\nIn the realm of Virtual Private Servers (VPS), DigitalOcean stands out as a beacon of reliability and innovation. Renowned for...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Home & Garden\n\n\n10 Transformative Scottsdale Window Coverings for Elegant Homes\nWindows serve as the eyes to a home, allowing in the warm embrace of sunlight and framing picturesque views of...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Contractors & Construction Equipment\n\n\n8 Key Insights into A&H Forensic Roofing: Expert Analysis & Solutions\nIntroduction to A&amp;H Forensic Roofing\r\nRoofing, often overlooked but undeniably vital, stands as the sentinel guarding our structures against the...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Home & Garden\n\n\n8 Powerful Mosquito Authority Solutions in Charleston SC\nWhen the allure of Charleston, SC meets the persistent hum of mosquitoes, a peculiar harmony emerges. Exploring the delicate equilibrium...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Health & Medicine\n\n\n11 Ways Helping Hands Family Empowers and Transforms Communities\nIntroduction to Helping Hands Family\r\nIn a world where every helping hand counts, organizations like&nbsp;Helping Hands Family&nbsp;shine as beacons of...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Travel & Transportation\n\n\n7 Luxurious Benefits of Choosing Our Savannah Limo Service\nAre you ready to elevate your travel experience in Savannah? Look no further than our premier&nbsp;Savannah Limo Service. With a...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Restaurants, Food & Beverages\n\n\n5 Irresistible Tijuana Tamales Delivered Fresh to Your Doorstep\nCraving the delectable flavors of authentic Mexican cuisine right at your doorstep? Look no further than&nbsp;Tijuana Tamales&nbsp;Meal Delivery! Our mission...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Home & Garden\n\n\n9 Compelling Reasons to Choose Cactus Plumbing and Air\nIntroduction to Cactus Plumbing and Air\r\nIn the intricate realm of home maintenance, few aspects are as crucial as plumbing...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Home & Garden\n\n\n10 Innovative Solar Solutions by Solaria Energy Solutions\nIn today&rsquo;s rapidly evolving world, where environmental concerns are taking center stage,&nbsp;Solaria Energy Solutions&nbsp;emerges as a beacon of light, quite...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Health & Medicine\n\n\n10 Ways Majestic Dentistry Transforms Your Dental Experience\nAre you in pursuit of a dental experience that blends expertise with warmth, precision with care? Look no further than&nbsp;Majestic...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Legal\n\n\n5 Ways Fiore Law Group Elevates Your Legal Experience\nWhen it comes to navigating the intricate landscape of legal matters, having a steadfast and experienced ally can make all...\nRead More \n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Legal\n\n\n5 Key Legal Services Offered by Bornstein & Bornstein Law Group\nIntroduction\r\nWhen it comes to navigating the intricate world of law, having a reliable and knowledgeable legal team by your...\nRead More \n\n\n\n\n\n\n\n\n\n                          ...
#  Document(metadata={'source': 'https://citylocalbiz.us/about', 'title': 'About Us - Local Directory Search', 'description': 'Discover the best businesses in the USA with our powerful local directory search. Locate services, products & more. Unleash the potential of local commerce.', 'language': 'en'}, page_content="\n\n\n\n\n\nAbout Us - Local Directory Search\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout Us\n\n\n\n\nHome\nAbout Us\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWHO WE ARE\n\n\nLet's Get Connected\n\n\n                                    At City Local Biz, we are a dynamic community-driven platform dedicated to bridging the gap between local businesses and their communities across the USA. We believe in the transformative power of local businesses in shaping vibrant cities\n                                \n\n\n\n\n\n\nOur Mission\n\n\n                                            At City Local Biz, our mission is to empower local businesses by providing a platform that bridges the gap between businesses and their communities. We believe that when local businesses thrive, communities thrive. Our goal is to make it easy for businesses to connect with their target audience and for customers to discover the gems that make their city unique.\n                                        \n\n\n\n\n\n\n\n\nOur Vision\n\n\n                                            At City Local Biz, our vision is to revolutionize the way businesses connect with their local communities. We envision a future where every local business, regardless of its size, has the opportunity to thrive and contribute to the vitality of its city. We're committed to being the driving force behind this transformation, providing innovative tools and resources that empower businesses to flourish and customers to discover the richness of their local economy.\n                                        \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHow It Works?\n\n                    Experience the ease of finding local businesses across the USA with our user-friendly platform. Simply enter your city and explore an extensive array of listings on our business directory, connecting you to the best in City Local Biz.\n                   \n\n\n\n\n\n\n\n\n\nExplore Diverse Listings:\nBrowse our extensive directory featuring a wide range of local businesses across the USA\n\n\n\n\n\n\n\n\n\nRefined Search:\nUse our intuitive search filters to narrow down your choices based on location, category, and ratings\n\n\n\n\n\n\n\n\n\nEngage and Connect:\nOnce you've found a business that resonates with you, engage further through detailed profiles, company posts & reviews.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nWhy Choose City Local Biz\n\n\n\n                                        We understand the unique challenges and opportunities that local businesses face. Our platform is tailored to address these needs, ensuring your business thrives in its local ecosystem\n                                    \n\n\nLocal Expertise\nUser-Friendly Experience\nImpactful Results\nEngaging Company Posts\nHigh-Visibility Listings\nCommunity Engagement\nLive Chat Support\nSponsored Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe\n\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps:// ...
#  Document(metadata={'source': 'https://citylocalbiz.us/contact', 'title': 'Get in Touch with City Local Biz - Contact Us Today', 'description': "Connect with City Local Biz! Reach out for inquiries, suggestions, or partnership opportunities. We're here to help. Contact us now!", 'language': 'en'}, page_content='\n\n\n\n\n\nGet in Touch with City Local Biz - Contact Us Today\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nContact Us\n\n\n\n\nHome\nContact Us\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nContact Us\n\n\n\n\n\n\n\nAddress\nUSA\n\n\n\n\n\n\n\nEmail\nSee\n\n\n\n\n\n\n\nChat\nLive Chat/Offline Chat\n\n\n\n\n\n\n\nContent Contribute\nContribute Form\n\n\n\n\n\n\nContact Us\n\n\n\n\n\n\n\nAddress\nUSA\n\n\n\n\n\n\n\nEmail\nSee\n\n\n\n\n\n\n\nChat\nLive Chat/Offline Chat\n\n\n\n\n\n\n\nContent Contribute\nContribute Form\n\n\n\n\n\n\n\nGet In Touch\n"Get In Touch" is a user-friendly form that invites visitors to effortlessly connect with us. Use this live chat to share your inquiries, feedback, or collaboration ideas, and our team will promptly respond to your messages.\n\n\n\n\n\n Send Message\n\n\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://citylocalbiz.us/sign-up#google_vignette', 'title': 'Join Our Business Directory: Register Today!', 'description': 'Unlock business growth with our directory. Register now to connect, network, and thrive. Empower your success!', 'language': 'en'}, page_content='\n\n\n\n\n\nJoin Our Business Directory: Register Today!\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nRegister to City Local Biz\n\n\n\n \nUsername *\n\n\n\n\n\n\n\n\nFull Name *\n\n\n\n\n\n\n\n\nEmail *\n\n\n\n\n\n\n\n\nPassword*\n\n\n\n\n\n\n\n\nConfirm Password*\n\n\n\n\n\n\n\n\n\n \xa0 Accept the Terms and Privacy\n\n\n  Sign Up\n\n\n\n\nOr\n\n\n\n Google\n\n\nFacebook\n\n\nGithub\n\n\nTwitter\n\n\n\n\nAlready have an account? Login\n\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://citylocalbiz.us/login', 'title': 'Secure Login to City Local Biz Directory', 'description': 'Access your City Local Biz account. Manage your local business businesses with ease. Join the comprehensive USA Business Directory today!', 'language': 'en'}, page_content='\n\n\n\n\n\nSecure Login to City Local Biz Directory\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin to City Local Biz\n\n\n\n \nEmail *\n\n\n\n\n\n\n\n\n\nPassword*\n\n\n\n\n\n\n\n\n\n\n\n \xa0 Remember me\n\n\nForgot Password?\n\n\n\n\n\n\n                                    Login\n                                \n\n\n\n\n\nOr\n\n\n\n\nGoogle\n\n\nFacebook\n\n\nGithub\n\n\nTwitter\n\n\n\n\nDon’t have an account? Register\n\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://citylocalbiz.us/package-price', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='\n\n\n\n\n\nChoose a Package - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nChoose a Package\nRisk free submission at anytime. no questions, no hastle\n\n\n\n\n\n\nBasic\n\n\n0/credits\n                                    \n\n\n\nBusiness Name\nBusiness Address\nPhone Number\nWebsite & Email\nShort Summary\nSingle Category\nLogo & Up to 2 Images\nGoogle Map & Amenities\nPrice Range\nBusiness Hours\nAdditional Information \nFAQs & Video Link\nPayment Methods\nSocial Profiles\nUp to 10 Services\nSEO Meta\nVerified Badge\nSponsored Badge (3 Months)\n\n\n\nChoose plan\n\n\n\n\n\n\nBest Value\n\n\nPremium \n\n\n250/credits\n                                    \n\n\n\nBusiness Name\nBusiness Address\nBusiness Phone\nWebsite & Email\nMultiple Category\nBusiness Hours\nLogo & Up to 20 Images\nShort and Long Details\nGoogle Map & Amenities\nAdditional Information \nPrice Range & Video Link\nUp to 10 FAQs\nPayment Methods\nSocial Profiles\nUp to 10 Services\nSEO Meta\nVerified Badge (Phone Verify)\nSponsored Badge (3 Months)\n\n\n\nChoose plan\n\n\n\n\n\n\nMedium \n\n\n100/credits\n                                    \n\n\n\nBusiness Name\nBusiness Address\nBusiness Phone\nWebsite & Email\nMultiple Category\nBusiness Hours\nLogo & Up to 5 Images\nShort and Long Details\nGoogle Map & Amenities\nAdditional Information \nPrice Range & Video Link\nUp to 5 FAQs\nPayment Methods\n3 Social Profiles\nUp to 10 Services\nSEO Meta\nVerified Badge (By Phone)\nSponsored Badge (1 Months)\n\n\n\nChoose plan\n\n\n\n\n\n\n\nNote: Insufficient balance? Earn Credit  for Free or Buy\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'),
#  Document(metadata={'source': 'https://citylocalbiz.us/states', 'title': 'Discover Top Businesses in USA States - City Local Biz', 'description': 'Find the best best services in USA States on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='\n\n\n\n\n\nDiscover Top Businesses in USA States - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll USA States\n\n\n\n\nHome\nAll USA States\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                                Alaska\n                                                99\n\n\n\n\n\n\n\n\n\n\n\n                                                Alabama\n                                                286\n\n\n\n\n\n\n\n\n\n\n\n                                                Arkansas\n                                                130\n\n\n\n\n\n\n\n\n\n\n\n                                                Arizona\n                                                739\n\n\n\n\n\n\n\n\n\n\n\n                                                California\n                                                3590\n\n\n\n\n\n\n\n\n\n\n\n                                                Colorado\n                                                613\n\n\n\n\n\n\n\n\n\n\n\n                                                Connecticut\n                                                236\n\n\n\n\n\n\n\n\n\n\n\n                                                District of Columbia\n                                                69\n\n\n\n\n\n\n\n\n\n\n\n                                                Delaware\n                                                96\n\n\n\n\n\n\n\n\n\n\n\n                                                Florida\n                                                2396\n\n\n\n\n\n\n\n\n\n\n\n                                                Georgia\n                                                800\n\n\n\n\n\n\n\n\n\n\n\n                                                Hawaii\n                                                80\n\n\n\n\n\n\n\n\n\n\n\n                                                Iowa\n                                                80\n\n\n\n\n\n\n\n\n\n\n\n                                                Idaho\n                                                127\n\n\n\n\n\n\n\n\n\n\n\n                                                Illinois\n                                                778\n\n\n\n\n\n\n\n\n\n\n\n                                                Indiana\n                                                320\n\n\n\n\n\n\n\n\n\n\n\n                                                Kansas\n                                                131\n\n\n\n\n\n\n\n\n\n\n\n                                                Kentucky\n                                                156\n\n\n\n\n\n\n\n\n\n\n\n                                                Louisiana\n                                                249\n\n\n\n\n\n\n\n\n\n\n\n                                                Massachusetts\n                                                373\n\n\n\n\n\n\n\n\n\n\n\n                                                Maryland\n                                                328\n\n\n\n\n\n\n\n\n\n\n\n                                                Maine\n                                                33\n\n\n\n\n\n\n\n\n\n\n\n                                                Michigan\n                                                406\n\n\n\n\n\n\n\n\n\n\n\n                                                Minnesota\n                                                296\n\n\n\n\n\n\n\n\n\n\n\n              ...
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='\n\n\n\n\n\nDiscover Top Businesses in any City - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nTop cities from United States\n\n\n\n\nHome\nTop Cities\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                New York\n                                                837\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Houston\n                                                395\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Los Angeles\n                                                380\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Miami\n                                                282\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Charleston\n                                                270\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Brooklyn\n                                                264\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Las Vegas\n                                                260\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Dallas\n                                                246\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Chicago\n                                                237\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Austin\n                                                218\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Phoenix\n                                                190\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                San Antonio\n                                                187\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Atlanta\n                                                174\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                San Diego\n                                                169\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Denver\n                                                163\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                New City\n                                                161\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Orlando\n                                                160\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Charlotte\n                                                137\n ...
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content="\n\n\n\n\n\nDiscover Top Businesses by Category - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Popular Categories\n\n\n\n\nHome\nAll Categories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAgriculture, Fishing & Forestry\n(5 company)\n\n\n\n\n\n\n\n\n\nArts & Entertainment\n(312 company)\n\n\n\n\n\n\n\n\n\nAutomotive\n(1406 company)\n\n\n\n\n\n\n\n\n\nBusiness & Professional Services\n(3452 company)\n\n\n\n\n\n\n\n\n\nContractors & Construction Equipment\n(3242 company)\n\n\n\n\n\n\n\n\n\nEducation\n(248 company)\n\n\n\n\n\n\n\n\n\nFinance & Insurance\n(913 company)\n\n\n\n\n\n\n\n\n\nHealth & Medicine\n(2635 company)\n\n\n\n\n\n\n\n\n\nHome & Garden\n(3210 company)\n\n\n\n\n\n\n\n\n\nIndustrial Supplies & Services\n(201 company)\n\n\n\n\n\n\n\n\n\nLegal\n(2033 company)\n\n\n\n\n\n\n\n\n\nManufacture & Wholesale\n(128 company)\n\n\n\n\n\n\n\n\n\nOrganization's & Government\n(164 company)\n\n\n\n\n\n\n\n\n\nOthers\n(846 company)\n\n\n\n\n\n\n\n\n\nPersonal Services & Care\n(810 company)\n\n\n\n\n\n\n\n\n\nPets\n(184 company)\n\n\n\n\n\n\n\n\n\nReal Estate, Moving & Storage\n(958 company)\n\n\n\n\n\n\n\n\n\nRestaurants, Food & Beverages\n(764 company)\n\n\n\n\n\n\n\n\n\nShopping & Speciality Stores\n(1335 company)\n\n\n\n\n\n\n\n\n\nSports & Recreation\n(290 company)\n\n\n\n\n\n\n\n\n\nTechnology\n(500 company)\n\n\n\n\n\n\n\n\n\nTelecommunications\n(46 company)\n\n\n\n\n\n\n\n\n\nTravel & Transportation\n(547 company)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe\n\n\n\n\n\n\n\n\n\n\nhttps://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/\n\n\n\n\n\n\n\n\n 2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n")]

# %%
len(docs)
# Out:
# 14

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=50)
documents = text_splitter.split_documents(docs)
documents
# Out:
# [Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Discover Local Businesses - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nJoin Us & Explore Thousands of Local Places\nFind the place you want and search the best place everything is here.\n\n\n\n\n\n\nKeywords\n\n\n\n\n\n\n\nWhere'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Select States\nAlabama (AL)\nAlaska (AK)\nAlberta (AB)\nArizona (AZ)\nArkansas (AR)\nBritish Columbia (BC)\nCalifornia (CA)\nColorado (CO)\nConnecticut (CT)\nDelaware (DE)\nDistrict of Columbia (DC)\nFlorida (FL)\nGeorgia (GA)\nHawaii (HI)\nIdaho (ID)\nIllinois (IL)\nIndiana (IN)\nIowa (IA)\nKansas (KS)\nKentucky (KY)\nLouisiana (LA)\nMaine (ME)\nManitoba (MB)\nMaryland (MD)\nMassachusetts (MA)\nMichigan (MI)\nMinnesota (MN)\nMississippi (MS)\nMissouri (MO)\nMontana (MT)\nNebraska (NE)\nNevada (NV)\nNew Brunswick (NB)'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Nebraska (NE)\nNevada (NV)\nNew Brunswick (NB)\nNew Hampshire (NH)\nNew Jersey (NJ)\nNew Mexico (NM)\nNew York (NY)\nNewfoundland and Labrador (NL)\nNorth Carolina (NC)\nNorth Dakota (ND)\nNorthwest Territories (NT)\nNova Scotia (NS)\nNunavut (NU)\nOhio (OH)\nOklahoma (OK)\nOntario (ON)\nOregon (OR)\nPennsylvania (PA)\nPrince Edward Island (PE)\nQuebec (QC)\nRhode Island (RI)\nSaskatchewan (SK)\nSouth Carolina (SC)\nSouth Dakota (SD)\nTennessee (TN)\nTexas (TX)\nUtah (UT)\nVermont (VT)\nVirginia (VA)\nWashington (WA)'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Vermont (VT)\nVirginia (VA)\nWashington (WA)\nWest Virginia (WV)\nWisconsin (WI)\nWyoming (WY)\nYukon (YT)'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Search\n\n\n\n\n\nPopular Search :\ngarage+door,\nsummers plumbing heating,\nheating, cooling,\nstellrr+insulation+,\nhunt’s kitchen\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nStates\nUSA & Canada top regions\n\n\n\n\n\n                                            California\n                                            3590\n\n\n\n\n                                            Texas\n                                            2634\n\n\n\n\n                                            Florida\n                                            2396'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='New York\n                                            2120\n\n\n\n\n                                            New Jersey\n                                            804\n\n\n\n\n                                            Georgia\n                                            800\n\n\n\n\n                                            Illinois\n                                            778'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Arizona\n                                            739\n\n\n\n\n                                            Pennsylvania\n                                            670\n\n\n\n\n                                            Colorado\n                                            613\n\n\n\nAll States\n\n\n\n\n\n\n\nCities\nUSA & Canada top cities\n\n\n\n\n\n                                            New York\n                                            837'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Houston\n                                            395\n\n\n\n\n                                            Los Angeles\n                                            380\n\n\n\n\n                                            Miami\n                                            282\n\n\n\n\n                                            Charleston\n                                            270'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Brooklyn\n                                            264\n\n\n\n\n                                            Las Vegas\n                                            260\n\n\n\n\n                                            Dallas\n                                            246\n\n\n\n\n                                            Chicago\n                                            237'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Austin\n                                            218\n\n\n\nTop Cities\n\n\n\n\n\n\n\nCategories\nUSA & Canada categories\n\n\n\n\n\n\n                                            Business Consultants\n                                            1311\n\n\n\n\n\n                                            Legal Services\n                                            1236'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Local Services\n                                            787\n\n\n\n\n\n                                            Health Services\n                                            781\n\n\n\n\n\n                                            Dentists\n                                            689\n\n\n\n\n\n                                            Garage Doors\n                                            592'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Automotive\n                                            525\n\n\n\n\n\n                                            Restaurants\n                                            520\n\n\n\n\n\n                                            Appliances\n                                            440\n\n\n\n\n\n                                            Insurance\n                                            410\n\n\n\nAll Categories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFeatured Companies'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Featured Companies\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nBuchannan Firm\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n452 Ada Dr SE #300 MI\nSee Phone\nhttps://www.buchananfirm.c..\n\n\n\n\n0 / 0 Rating\n\n\n$$\n\n\n\n Legal\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='$$\n\n\n\n Legal\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nHulett Environmental Services - Pest & Termite Control\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n4525 Vineland Rd, Suite 206 FL\nSee Phone\nhttps://www.bugs.com/?camp..\n\n\n\n\n0 / 0 Rating\n\n\n$$\n\n\n\n Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='$$\n\n\n\n Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\n24 Hour Laundry\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n7133 Chimney Rock Rd TX\nSee Phone\nhttps://laundromathoustont..\n\n\n\n\n5 / 1 Rating\n\n\n$$\n\n\n\n Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='$$\n\n\n\n Home\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nLaw Office of Scott Righthand PC\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n275 Battery St, #1300 CA\nSee Phone\nhttp://www.righthandfirm.c..\n\n\n\n\n0 / 0 Rating\n\n\n$$\n\n\n\n Legal'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content="0 / 0 Rating\n\n\n$$\n\n\n\n Legal\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPlaces you can't miss\nShowcasing the newest local companies that have joined our platform to better serve your needs.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nFirst Service Consulting\n\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n\n8000 NW 7th Street, Suite 202,Miami,FL,33126,USA, Miami, FL 33126 \nSee Phone\n\n\n   Legal"),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Legal\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nUp N Go Moving & Storage\n\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n\n4700 Northern Blvd, Queens, NY 11101 \nSee Phone\n\n\n   Real Estate, Moving & Storage\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nST Towing LLC'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='ST Towing LLC\n\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n\n7006 McComber St, West Sacramento, CA 95828 \nSee Phone\n\n\n   Automotive\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSupreme Garage Door Repair'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='Supreme Garage Door Repair\n\n                                                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n\n1400 W Irving Blvd #302, Irving, TX 75061, United States, Irving, TX 75061 \nSee Phone\n\n\n   Home & Garden\n\n\n\n\n\n\n\n\nView More\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='View More\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/', 'title': 'Discover Local Businesses - City Local Biz', 'description': 'Explore top-rated local businesses in the USA on City Local Biz. Find services, restaurants, shops, health care and more. Empowering your local choices!', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Charter Spectrum Cable & Internet - Portland, OR\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCharter Spectrum Cable & Internet\n                                                                                \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\nUnclaim'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Unclaim\n\n\n\n\n                                                    This business has not yet been claimed by the owner or a representative.\n                                                    \n\nClaim this business to view business & Make it easier for local customers to find you by keeping your business with Trust.\n                                                    \n\n\n\n\n\n\n0/\xa0 0 Rating\n                                      \n\n\n\n855-441-9844'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='855-441-9844\n\n\n                                                  Visit Website \n\n\n\n\n\n3055 NW Yeon Ave #546 Portland OR 97210 \n\n\n\n\nSubmitted By  charterportland\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\nSubmit Review\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nTechnology\n\n\n\n\n ⇨ Internet Services\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAbout this business\n\n\n\n\n\n\n\n\n\nGallery\n\n\n\n\n\n\n\n\n\n\n\nMap\n\n\n\n\n\n\n\n\n\n\n\n\nReview\n\n\nLeave A Review\n\n\n\n\n\n0\n\n0 review\n\n\n\n\nService\n\n\n\nCo-operation\n\n\n\nQuality\n\n\n\nPrice\n\n\n\n\n\n\n\n\n\n\n\n\nAdd Review\n\n\n \n\n\nService\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nCo-Operation\n\n\n★\n\n★'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Service\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nCo-Operation\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nQuality\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\nPrice\n\n\n★\n\n★\n\n★\n\n★\n\n★\n\n\n\n\n\n\n\n\nSubmit Review\n\n\n\n\n\n\n\n\n\n\n\n\nBusiness Information\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nCharter Spectrum Cable & Internet\n                                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\nPortland OR\n\n\n\n\n\n\nCategories:'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Portland OR\n\n\n\n\n\n\nCategories:\n\n\n\n\n                                                                Technology\n                                                            \n\n\n\n\n\nPhone Number:\n\n\n855-441-9844\n\n\n\n\nPublish Date:\n\n\n 5 years ago\n\n\n\n\n\n                                                    Visit Website   \n\n\n\n\n\n\n\n\nNearby Company\n\n\n\n\n\n\n\n\nWeaver Synthetics\n 5730 SW Shattuck Rd, Portland OR\n  503-244-9394'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content="television price in bangladesh\n 1376 Kincheloe Road, Portland OR\n  5034754664 \n\n\n\n\n\n\n\n\n\nIBR Infotech\n 2759 NE Whitaker Way, # F133, Portland, Oregon, 97230, US, Portland OR\n  5035757893 \n\n\n\n\n\n\n\n\n\nHappy Haus\n Portland, OR, USA, Portland OR\n  9713302226 \n\n\n\n\n\n\n\n\n\nAva Health\n 5117 SE Powell Blvd. #3, US, Portland OR\n  (503) 777-7097 \n\n\n\n\n\n\n\n\n\nOnie's Auto - Cash for Cars\n 5325 N Columbia Blvd, Portland OR\n  971-284-1906"),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Falcon Services\n 10180 SW Park Way, Portland OR\n  (503) 208-4709 \n\n\n\n\n\n\n\n\n\nAffordable Junk Removal LLC\n 6639 SE 65th Ave, Portland OR\n  503-354-7887 \n\n\n\n\n\n\n\n\n\nSunset Heating & Cooling\n 607 S Idaho Street #100, Portland OR\n  (503) 234-0611 \n\n\n\n\n\n\n\n\n\nServerpartsworld\n Serverpartsworld International, Inc. 15727 NE Russell St, Portland OR\n  (503) 252-9361 \n\n\n\n\n\n\n\nPrice Range\n\n\n\nN/A\n\n\n\n\n\n Related Search'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Price Range\n\n\n\nN/A\n\n\n\n\n\n Related Search\n\n\n\ngarage+door\nsummers plumbing heating\nheating, cooling\nstellrr+insulation+\nhunt’s kitchen\nsteck realty & remodeling\nwinters & yonker\nwalter & lewis funeral home\nwalter & lewis funeral\ntitanium plumbing & remodeling\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nYou May Also Be Interested In\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Save\n\n\n\n\n\n\n\n\n\n\n\n\nHeaven Essentials Virt..\n                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n1746 East Silver Star Road, #275 FL\nSee Phone\nhttp://heavenessentialsvs...\n\n\n\n\n0 /  0 Rating\n\n\n  Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nSales Leads Design\n                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n8679 Escondido Way E. FL\nSee Phone\nhttp://www.salesleadsdesig..\n\n\n\n\n0 /  0 Rating\n\n\n  Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nLive Oak IT\n                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\nPO Box 9126, Austin, Texas, 78766, United States TX\nSee Phone\nhttps://goliveoak.com/\n\n\n\n\n0 /  0 Rating\n\n\n  Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSave\n\n\n\n\n\n\n\n\n\n\n\n\nTechArk Solutions Webs..\n                                                                                            \nThis business has not yet been verified by the company owner or a representative.\n\n\n\n\n\n415 W. York St, Suite #103 VA\nSee Phone\nhttp://www.gotechark.com\n\n\n\n\n0 /  0 Rating\n\n\n  Technology\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='Subscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/listing/charter-spectrum-cable-&-internet-portland-or-97210', 'title': 'Charter Spectrum Cable & Internet - Portland, OR', 'description': 'You can find your local business on City Local Biz. Like as Business, Health, Home & Garden, Automobile, Transport, Law etc', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='Choose a Package - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nBuy Credits\nRisk free purchase at anytime. no questions, no hastle\n\n\n\n\n\n\nMini\n50 Credits\n\n\n\n0 Bonus Credits\n50 Credits\nunlimited Validity\n\n\n\nBuy $3.49\n\n\n\n\n\n\nMedium\n100 Credits\n\n\n\n5 Bonus Credits\n100 Credits\nunlimited Validity\n\n\n\nBuy $4.99\n\n\n\n\n\n\nLarge\n200 Credits'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='Buy $4.99\n\n\n\n\n\n\nLarge\n200 Credits\n\n\n\n10 Bonus Credits\n200 Credits\nunlimited Validity\n\n\n\nBuy $9.99\n\n\n\n\n\n\nBronze\n400 Credits\n\n\n\n20 Bonus Credits\n400 Credits\nunlimited Validity\n\n\n\nBuy $19.99\n\n\n\n\n\n\nSilver\n1000 Credits\n\n\n\n80 Bonus Credits\n1000 Credits\nunlimited Validity\n\n\n\nBuy $49.99\n\n\n\n\n\n\nGold\n2000 Credits\n\n\n\n200 Bonus Credits\n2000 Credits\nunlimited Validity\n\n\n\nBuy $99.00\n\n\n\n\n\n\nDiamond\n10000 Credits\n\n\n\n600 Bonus Credits\n10000 Credits\nunlimited Validity\n\n\n\nBuy $499.00\n\n\n\n\n\n\nPlatinum\n20000 Credits'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='Buy $499.00\n\n\n\n\n\n\nPlatinum\n20000 Credits\n\n\n\n1200 Bonus Credits\n20000 Credits\nunlimited Validity\n\n\n\nBuy $999.00\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin with City Local Biz\n\n\n\n\n\n  Email:\n\n\n\n Password:\n\n\n\n\n\nClose\nLogin'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/buy-credit', 'title': 'Choose a Package - City Local Biz', 'description': 'Risk free Upgrade or Cancel at anytime. no questions, no hastle', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Terms and Condition - City Local Biz \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nTerms and Conditions\n\n\n\n\nHome\nTerms and Conditions\n\n\n\n\n\n\n\n\n\n\n\n\n\nLast updated: August 1, 2025'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Last updated: August 1, 2025\n\n\n\n\n                        Welcome to City Local Biz! By accessing and using our website, you agree to comply with the following terms and conditions. Please read them carefully.\n                    \n\n\nAcceptance of Terms'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Acceptance of Terms\n\n                        By using City Local Biz, you agree to abide by these terms, our Privacy Policy, and any additional guidelines or rules that are displayed on our website. If you do not agree with any part of these terms, kindly refrain from using our services.\n                    \n\n\nUser Responsibilities'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='User Responsibilities\n\n                        Users of City Local Biz must be at least 18 years old. You are responsible for maintaining the confidentiality of your account information and agree to take sole responsibility for all activities that occur under your account.\n                    \n\n\nBusiness Listings and Content'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Business Listings and Content\n\n                        Businesses listed on City Local Biz are responsible for the accuracy and legality of their content. We reserve the right to remove any content that violates our guidelines or is deemed inappropriate, offensive, or fraudulent.\n                    \n We are not accepting thses type of content listed'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Adult Content\n  Alcohol Content\n  Casino Content\n  Cannabis Content\n  Fraud and Scams\n  Gambling Content\n  Malware Content\n  Pornography Content\n  Terrorist Content\n  Weeds Content\n\n\n\nThird-Party Links and Content\n\n                        Our website may contain links to third-party websites, services, or content that are not owned or controlled by City Local Biz. We are not responsible for the content, privacy policies, or practices of these third parties.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Limitation of Liability\n\n                        City Local Biz and its affiliates shall not be liable for any indirect, incidental, special, consequential, or punitive damages arising from your use of the website or any content therein.\n                    \n\n\nIntellectual Property\n\n                        All content on City Local Biz, including text, graphics, logos, and images, is the property of City Local Biz or its licensors and is protected by copyright laws.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Changes to Terms\n\n                        City Local Biz reserves the right to modify or replace these terms at any time. Your continued use of the website after changes have been made signifies your acceptance of the revised terms.\n                    \n\n\n\n                        For any questions or concerns regarding our terms and conditions, please contact us\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='Subscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/terms-conditions', 'title': 'Terms and Condition - City Local Biz ', 'description': 'Explore City Local Biz terms and guidelines for businesses. Empower your local business journey with our transparent and supportive platform', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='Privacy Policy | Safeguarding Your Data - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nPrivacy Policy\n\n\n\n\nHome\nPrivacy Policy\n\n\n\n\n\n\n\n\n\n\n\n\n\nLast updated: August 1, 2025'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='Last updated: August 1, 2025\n\n\n\n                    Our Privacy Policy was last updated and posted on August 1, 2025. It governs the privacy terms of our Website, located at https://citylocalbiz.us, sub-domains, and any associated web-based and mobile applications (collectively, “Website”), as owned and operated by City Local Biz. Any capitalized terms not defined in our Privacy Policy, have the meaning as specified in our Terms of Service.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='Your privacy is very important to us. Accordingly, we have developed this Policy in order for you to understand how we collect, use, communicate and disclose and make use of personal information. We use your Personal Information only for providing and improving the Site. By using the Site, you agree to the collection and use of information in accordance with this policy. Unless otherwise defined in this Privacy Policy, terms used in this Privacy Policy have the same meanings'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='in this Privacy Policy have the same meanings as in our Terms and Conditions, accessible at https://citylocalbiz.us. The following outlines our privacy policy.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='* Before or at the time of collecting personal information, we will identify the purposes for which information is being collected.\n                        \n\n                            * We will collect and use of personal information solely with the objective of fulfilling those purposes specified by us and for other compatible purposes, unless we obtain the consent of the individual concerned or as required by law.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='* We will only retain personal information as long as necessary for the fulfillment of those purposes.\n                        \n\n                            * We will collect personal information by lawful and fair means and, where appropriate, with the knowledge or consent of the individual concerned.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='* Personal data should be relevant to the purposes for which it is to be used, and, to the extent necessary for those purposes, should be accurate, complete, and up-to-date.\n                        \n\n                            * We will protect personal information by reasonable security safeguards against loss or theft, as well as unauthorized access, disclosure, copying, use or modification.'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='* We will make readily available to customers information about our policies and practices relating to the management of personal information.\n                        \n\n\n\nYour Privacy'),
#  Document(metadata={'source': 'https://citylocalbiz.us/privacy-policy', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='City Local Biz follows all legal requirements to protect your privacy. Our Privacy Policy is a legal statement that explains how we may collect information from you, how we may share your information, and how you can limit our sharing of your information. We utilize the Personal Data you offer in a way that is consistent with this Personal privacy Policy. If you provide Personal Data for a particular reason, we could make use of the Personal Data in connection with the'),
# ...
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Katy\n                                                39\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Riverside\n                                                39\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Hollywood\n                                                38'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Omaha\n                                                38\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Gilbert\n                                                38\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Tempe\n                                                38'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Staten Island\n                                                37\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Marietta\n                                                37\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Glendale\n                                                37'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Birmingham\n                                                37\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Glendale\n                                                37\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Queens\n                                                36'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Jersey City\n                                                36\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Baton Rouge\n                                                36\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Costa Mesa\n                                                35'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Saint Petersburg\n                                                35\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Newport Beach\n                                                35'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Alpharetta\n                                                34\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Aurora\n                                                34\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Fort Myers\n                                                34'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Knoxville\n                                                33\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Clearwater\n                                                33\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Honolulu\n                                                33'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='California City\n                                                32\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Boise\n                                                32'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Corpus Christi\n                                                32\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Columbia\n                                                32\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Vancouver\n                                                31'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Toronto\n                                                31\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Toledo\n                                                31\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                Burbank\n                                                31'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='Milwaukee\n                                                31\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/cities', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='Discover Top Businesses by Category - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nAll Popular Categories\n\n\n\n\nHome\nAll Categories\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nAgriculture, Fishing & Forestry\n(5 company)\n\n\n\n\n\n\n\n\n\nArts & Entertainment\n(312 company)\n\n\n\n\n\n\n\n\n\nAutomotive\n(1406 company)\n\n\n\n\n\n\n\n\n\nBusiness & Professional Services\n(3452 company)'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content="Contractors & Construction Equipment\n(3242 company)\n\n\n\n\n\n\n\n\n\nEducation\n(248 company)\n\n\n\n\n\n\n\n\n\nFinance & Insurance\n(913 company)\n\n\n\n\n\n\n\n\n\nHealth & Medicine\n(2635 company)\n\n\n\n\n\n\n\n\n\nHome & Garden\n(3210 company)\n\n\n\n\n\n\n\n\n\nIndustrial Supplies & Services\n(201 company)\n\n\n\n\n\n\n\n\n\nLegal\n(2033 company)\n\n\n\n\n\n\n\n\n\nManufacture & Wholesale\n(128 company)\n\n\n\n\n\n\n\n\n\nOrganization's & Government\n(164 company)\n\n\n\n\n\n\n\n\n\nOthers\n(846 company)\n\n\n\n\n\n\n\n\n\nPersonal Services & Care\n(810 company)"),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='Personal Services & Care\n(810 company)\n\n\n\n\n\n\n\n\n\nPets\n(184 company)\n\n\n\n\n\n\n\n\n\nReal Estate, Moving & Storage\n(958 company)\n\n\n\n\n\n\n\n\n\nRestaurants, Food & Beverages\n(764 company)\n\n\n\n\n\n\n\n\n\nShopping & Speciality Stores\n(1335 company)\n\n\n\n\n\n\n\n\n\nSports & Recreation\n(290 company)\n\n\n\n\n\n\n\n\n\nTechnology\n(500 company)\n\n\n\n\n\n\n\n\n\nTelecommunications\n(46 company)\n\n\n\n\n\n\n\n\n\nTravel & Transportation\n(547 company)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSubscribe Our Newsletter'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='Subscribe Our Newsletter\n\n                    Stay in the loop and never miss out on updates – subscribe to our newsletter for the latest news, offers, and insights.\n                   \n\n\n\n\n\nSubscribe'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='https://journaltokaz.org/\nhttps://cfe.kneu.edu.ua/\nhttps://prograddb.unesp.br/\nhttps://jurnal.pppkmi.org/\nhttps://journal.unsuri.ac.id/\nhttps://iaitfdumai.ac.id/\nhttps://uwgm.ac.id/\nhttps://febi.iainpalopo.ac.id/\nhttps://artstudies.pdpu.edu.ua/\nhttps://fp.uisu.ac.id/\nhttps://journal.unigres.ac.id/\nhttps://ojsstikesbanyuwangi.com/\nhttps://ejournal.nusamandiri.ac.id/\nhttps://journal-stiehidayatullah.ac.id/\nhttps://sirventygranados.com/\nhttps://revistas.uca.es/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='https://revistas.uca.es/\nhttps://revistas.uca.es/index.php/hachetetepe\nhttps://ejournal.uinsaizu.ac.id/\nhttps://sidhara.bkkbn.go.id/'),
#  Document(metadata={'source': 'https://citylocalbiz.us/categories', 'title': 'Discover Top Businesses by Category - City Local Biz', 'description': 'Explore a wide range of businesses categorized for your convenience. Find the services you need quickly and easily.', 'language': 'en'}, page_content='2025City Local Biz| All Rights Reserved\n\n\n\n\n\n\nHome|\n\n\nCategory|\n\n\nPrices|\n\n\nTerms|\n\n\nPrivacy|\n\n\nBlog|\n\n\nAbout|\n\n\nContact')]

# %%
len(documents)
# Out:
# 219

# %% [markdown]
# #### Embedding the all documents

# %%
embeddings = HuggingFaceEmbeddings(model='all-MiniLM-L6-v2')

# %%
# save chroma db vector database
Chroma.from_documents(documents, embedding=embeddings, persist_directory="./chroma_db")

# %%
# load chroma db
vector_store = Chroma(persist_directory="./chroma_db", embedding_function=embeddings)

# %%
vector_store.similarity_search("how may city in there website")
# Out:
# [Document(id='9b054f4e-3974-4b43-8556-ea8db063dac8', metadata={'language': 'en', 'title': 'Discover Top Businesses in any City - City Local Biz', 'description': 'Find the best best services in USA cities on City Local Biz. Explore a curated directory for services, restaurants, and more. Empower your city experience!', 'source': 'https://citylocalbiz.us/cities'}, page_content='Discover Top Businesses in any City - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\n\nTop cities from United States\n\n\n\n\nHome\nTop Cities\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n                                            \n                                                New York\n                                                837'),
#  Document(id='d273f24f-655f-4a0f-bde8-635d3b944a37', metadata={'title': 'All Blogs - City Local Biz', 'description': 'Find your favorite blogs', 'language': 'en', 'source': 'https://citylocalbiz.us/blog'}, page_content='All Blogs - City Local Biz\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nLogin\n/\nRegister\n\n\n Add Listing\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nHome\n\n\nLogin / Register\n\n\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nOur Blogs\n\n\n\n\nHome\nBlog\n\n\n\n\n\n\n\n\n\n\n\n\nShowing\n 1-12\nof\n37 Result’s\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSep 29, 2024\n\n\n Technology'),
#  Document(id='ed687f27-1659-45a6-8dcd-0fa7df95a3e8', metadata={'title': 'About Us - Local Directory Search', 'description': 'Discover the best businesses in the USA with our powerful local directory search. Locate services, products & more. Unleash the potential of local commerce.', 'source': 'https://citylocalbiz.us/about', 'language': 'en'}, page_content='Our Mission\n\n\n                                            At City Local Biz, our mission is to empower local businesses by providing a platform that bridges the gap between businesses and their communities. We believe that when local businesses thrive, communities thrive. Our goal is to make it easy for businesses to connect with their target audience and for customers to discover the gems that make their city unique.\n                                        \n\n\n\n\n\n\n\n\nOur Vision'),
#  Document(id='27bf0c25-3cfa-4d25-b787-4e77189d739c', metadata={'language': 'en', 'title': 'About Us - Local Directory Search', 'source': 'https://citylocalbiz.us/about', 'description': 'Discover the best businesses in the USA with our powerful local directory search. Locate services, products & more. Unleash the potential of local commerce.'}, page_content="At City Local Biz, our vision is to revolutionize the way businesses connect with their local communities. We envision a future where every local business, regardless of its size, has the opportunity to thrive and contribute to the vitality of its city. We're committed to being the driving force behind this transformation, providing innovative tools and resources that empower businesses to flourish and customers to discover the richness of their local")]

# %%
retriver = vector_store.as_retriever()
result = retriver.invoke("how may states in there website")
result[0].page_content
# Out:
# 'Select States\nAlabama (AL)\nAlaska (AK)\nAlberta (AB)\nArizona (AZ)\nArkansas (AR)\nBritish Columbia (BC)\nCalifornia (CA)\nColorado (CO)\nConnecticut (CT)\nDelaware (DE)\nDistrict of Columbia (DC)\nFlorida (FL)\nGeorgia (GA)\nHawaii (HI)\nIdaho (ID)\nIllinois (IL)\nIndiana (IN)\nIowa (IA)\nKansas (KS)\nKentucky (KY)\nLouisiana (LA)\nMaine (ME)\nManitoba (MB)\nMaryland (MD)\nMassachusetts (MA)\nMichigan (MI)\nMinnesota (MN)\nMississippi (MS)\nMissouri (MO)\nMontana (MT)\nNebraska (NE)\nNevada (NV)\nNew Brunswick (NB)'

# %%
prompt = ChatPromptTemplate.from_template(
    """
    You are a helpful and knowledgeable AI assistant for a directory website. 
    Answer the following user question using only the information provided in the context below.

    <context>
    {context}
    </context>

    Question: {input}

    If the answer is not in the context, respond with:
    "I’m sorry, I don’t have enough information to answer that."

    Answer in a clear and concise way.
    """
)

# %%
qa_chain = create_stuff_documents_chain(llm=llm, prompt=prompt)
rag_chain = create_retrieval_chain(retriver, qa_chain)

# %%
response = rag_chain.invoke({"input": "What is the privace and policy?"})

# %%
response
# Out:
# {'input': 'What is the privace and policy?',
#  'context': [Document(id='6f2cab63-279e-4e2e-8db0-d8d7d0e5cfcd', metadata={'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'language': 'en', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'source': 'https://citylocalbiz.us/privacy-policy'}, page_content='Privacy Policy Updates'),
#   Document(id='5d800bbe-81a4-4630-9220-45c025ce5a0a', metadata={'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'source': 'https://citylocalbiz.us/privacy-policy', 'language': 'en', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience'}, page_content='in this Privacy Policy have the same meanings as in our Terms and Conditions, accessible at https://citylocalbiz.us. The following outlines our privacy policy.'),
#   Document(id='11351f12-6274-45f9-808d-9ce8bb093559', metadata={'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz', 'source': 'https://citylocalbiz.us/privacy-policy', 'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'language': 'en'}, page_content='Your privacy is very important to us. Accordingly, we have developed this Policy in order for you to understand how we collect, use, communicate and disclose and make use of personal information. We use your Personal Information only for providing and improving the Site. By using the Site, you agree to the collection and use of information in accordance with this policy. Unless otherwise defined in this Privacy Policy, terms used in this Privacy Policy have the same meanings'),
#   Document(id='86df2443-7e08-4874-8518-0faa1ff748f8', metadata={'description': 'Our Privacy Policy ensures your data security. Discover how we protect your information. Trust City Local Biz for a safe online experience', 'source': 'https://citylocalbiz.us/privacy-policy', 'language': 'en', 'title': 'Privacy Policy | Safeguarding Your Data - City Local Biz'}, page_content='Security')],
#  'answer': 'The privacy policy is outlined to inform users how their personal information is collected, used, communicated, disclosed, and utilized to provide and improve the Site.'}

# %%
response['answer']
# Out:
# 'The privacy policy is outlined to inform users how their personal information is collected, used, communicated, disclosed, and utilized to provide and improve the Site.'

# %%
response = rag_chain.invoke({"input": "What is the Terms and Conditions?"})

# %%
response['answer']
# Out:
# 'The Terms and Conditions of City Local Biz include agreements limiting the use of information and guidelines for collecting and using personal information, such as: \n1. Identifying the purposes for which information is being collected before or at the time of collecting personal information.\n2. Collecting and using personal information solely with the objective of fulfilling those purposes specified and for other compatible purposes, unless consent is obtained or as required by law.'

# %% [markdown]
# #### Add Chat history
